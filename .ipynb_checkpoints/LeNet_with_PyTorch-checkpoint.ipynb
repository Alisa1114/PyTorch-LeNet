# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
import torch.utils.data as dset
from torchvision import datasets, transforms

# %%
#transform
transform=transforms.Compose([transforms.ToTensor(),
               transforms.Normalize((0.5,),(0.5,)),])

# %%
#!wget www.di.ens.fr/~lelarge/MNIST.tar.gz
#!tar -zxvf MNIST.tar.gz

# %%
from torchvision.datasets import MNIST

transform = transforms.Compose([transforms.ToTensor()])
trainSet = MNIST(root = './', train=True, download=False, transform=transform)
testSet = MNIST(root = './', train=False, download=False, transform=transform)
trainLoader=dset.DataLoader(trainSet,batch_size=64,shuffle=True)
testLoader=dset.DataLoader(testSet,batch_size=64,shuffle=False)

# %%
import matplotlib.pyplot as plt

img, label = trainSet[0]
plt.imshow(img.squeeze(), cmap="gray")
plt.show()
print("label = "+str(label))
# Out:
# label = 5

# %%
#LeNet-Model
class LeNet_Model(nn.Module):
  def __init__(self):
    super(LeNet_Model,self).__init__()
    self.conv1=nn.Conv2d(1,6,5,padding=2)
    self.conv2=nn.Conv2d(6,16,5)
    self.dropout1=nn.Dropout(p=0.25)
    self.dropout2=nn.Dropout(p=0.5)
    self.fc1=nn.Linear(16*5*5,120)
    self.fc2=nn.Linear(120,84)
    self.fc3=nn.Linear(84,10)

  def forward(self,x):
    x=F.max_pool2d(F.relu(self.conv1(x)),(2,2))
    x=self.dropout1(x)
    x=F.max_pool2d(F.relu(self.conv2(x)),2)
    x=x.view(-1,self.num_flat_feature(x))
    x=F.relu(self.fc1(x))
    x=F.relu(self.fc2(x))
    x=self.dropout2(x)
    x=self.fc3(x)
    x=F.softmax(x,dim=1)
    return x

  def num_flat_feature(self,x):
    size=x.size()[1:]
    num_features=1
    for s in size:
      num_features*=s
    return num_features

model=LeNet_Model()
print(model)
# Out:
# LeNet_Model(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (dropout2): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=400, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
#parameters
batch_size=64
num_epoch=20
lr=0.0006
criterion=nn.CrossEntropyLoss()
optimizer=optim.SGD(model.parameters(),lr=0.002,momentum=0.9)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
print(torch.cuda.get_device_name(0))
# Out:
# Using device: cuda
# GeForce RTX 3060 Laptop GPU

# %%
#train
model = model.to(device)
total_step=len(trainLoader)
loss_list=[]
acc_list=[]
for epoch in range(num_epoch):
  running_loss=0.0
  for i,(images,labels) in enumerate(trainLoader,0):
    optimizer.zero_grad()
    images = images.to(device)
    labels = labels.to(device)
    outputs=model(images)
    loss=criterion(outputs,labels)
    loss.backward()
    optimizer.step()
    total=labels.size(0)
    _,predicted=torch.max(outputs.data,1)
    correct=(predicted==labels).sum().item()
    acc_list.append(correct/total)

    if (i+1)%batch_size==0:
      print('Epoch[{}/{}] - Step[{},{}] - Loss: {:.4f} - Accuracy: {:.2f}%'.format(epoch+1,num_epoch,i+1,total_step,loss.item(),(correct/total)*100))
# Out:
# Epoch[1/20] - Step[64,938] - Loss: 2.3020 - Accuracy: 9.38%
# Epoch[1/20] - Step[128,938] - Loss: 2.3024 - Accuracy: 9.38%
# Epoch[1/20] - Step[192,938] - Loss: 2.3017 - Accuracy: 18.75%
# Epoch[1/20] - Step[256,938] - Loss: 2.3020 - Accuracy: 14.06%
# Epoch[1/20] - Step[320,938] - Loss: 2.3019 - Accuracy: 9.38%
# Epoch[1/20] - Step[384,938] - Loss: 2.3009 - Accuracy: 12.50%
# Epoch[1/20] - Step[448,938] - Loss: 2.3012 - Accuracy: 14.06%
# Epoch[1/20] - Step[512,938] - Loss: 2.3020 - Accuracy: 18.75%
# Epoch[1/20] - Step[576,938] - Loss: 2.3029 - Accuracy: 7.81%
# Epoch[1/20] - Step[640,938] - Loss: 2.3026 - Accuracy: 14.06%
# Epoch[1/20] - Step[704,938] - Loss: 2.3009 - Accuracy: 15.62%
# Epoch[1/20] - Step[768,938] - Loss: 2.3028 - Accuracy: 7.81%
# Epoch[1/20] - Step[832,938] - Loss: 2.3040 - Accuracy: 7.81%
# Epoch[1/20] - Step[896,938] - Loss: 2.3034 - Accuracy: 9.38%
# Epoch[2/20] - Step[64,938] - Loss: 2.3009 - Accuracy: 14.06%
# Epoch[2/20] - Step[128,938] - Loss: 2.3009 - Accuracy: 12.50%
# Epoch[2/20] - Step[192,938] - Loss: 2.3012 - Accuracy: 15.62%
# Epoch[2/20] - Step[256,938] - Loss: 2.3005 - Accuracy: 17.19%
# Epoch[2/20] - Step[320,938] - Loss: 2.3004 - Accuracy: 12.50%
# Epoch[2/20] - Step[384,938] - Loss: 2.3007 - Accuracy: 9.38%
# Epoch[2/20] - Step[448,938] - Loss: 2.2992 - Accuracy: 15.62%
# Epoch[2/20] - Step[512,938] - Loss: 2.3017 - Accuracy: 9.38%
# Epoch[2/20] - Step[576,938] - Loss: 2.3005 - Accuracy: 12.50%
# Epoch[2/20] - Step[640,938] - Loss: 2.3012 - Accuracy: 6.25%
# Epoch[2/20] - Step[704,938] - Loss: 2.2980 - Accuracy: 15.62%
# Epoch[2/20] - Step[768,938] - Loss: 2.2976 - Accuracy: 17.19%
# Epoch[2/20] - Step[832,938] - Loss: 2.2973 - Accuracy: 18.75%
# Epoch[2/20] - Step[896,938] - Loss: 2.3010 - Accuracy: 9.38%
# Epoch[3/20] - Step[64,938] - Loss: 2.2980 - Accuracy: 12.50%
# Epoch[3/20] - Step[128,938] - Loss: 2.2982 - Accuracy: 14.06%
# Epoch[3/20] - Step[192,938] - Loss: 2.2965 - Accuracy: 10.94%
# Epoch[3/20] - Step[256,938] - Loss: 2.2952 - Accuracy: 17.19%
# Epoch[3/20] - Step[320,938] - Loss: 2.2973 - Accuracy: 12.50%
# Epoch[3/20] - Step[384,938] - Loss: 2.2910 - Accuracy: 21.88%
# Epoch[3/20] - Step[448,938] - Loss: 2.2904 - Accuracy: 18.75%
# Epoch[3/20] - Step[512,938] - Loss: 2.2881 - Accuracy: 15.62%
# Epoch[3/20] - Step[576,938] - Loss: 2.2921 - Accuracy: 9.38%
# Epoch[3/20] - Step[640,938] - Loss: 2.2923 - Accuracy: 12.50%
# Epoch[3/20] - Step[704,938] - Loss: 2.2759 - Accuracy: 14.06%
# Epoch[3/20] - Step[768,938] - Loss: 2.2831 - Accuracy: 10.94%
# Epoch[3/20] - Step[832,938] - Loss: 2.2421 - Accuracy: 21.88%
# Epoch[3/20] - Step[896,938] - Loss: 2.2374 - Accuracy: 34.38%
# Epoch[4/20] - Step[64,938] - Loss: 2.2250 - Accuracy: 31.25%
# Epoch[4/20] - Step[128,938] - Loss: 2.1509 - Accuracy: 37.50%
# Epoch[4/20] - Step[192,938] - Loss: 2.0908 - Accuracy: 42.19%
# Epoch[4/20] - Step[256,938] - Loss: 2.0051 - Accuracy: 57.81%
# Epoch[4/20] - Step[320,938] - Loss: 2.0292 - Accuracy: 45.31%
# Epoch[4/20] - Step[384,938] - Loss: 1.9469 - Accuracy: 54.69%
# Epoch[4/20] - Step[448,938] - Loss: 1.9151 - Accuracy: 56.25%
# Epoch[4/20] - Step[512,938] - Loss: 1.8979 - Accuracy: 56.25%
# Epoch[4/20] - Step[576,938] - Loss: 1.8553 - Accuracy: 60.94%
# Epoch[4/20] - Step[640,938] - Loss: 1.9883 - Accuracy: 53.12%
# Epoch[4/20] - Step[704,938] - Loss: 1.9016 - Accuracy: 56.25%
# Epoch[4/20] - Step[768,938] - Loss: 1.8509 - Accuracy: 67.19%
# Epoch[4/20] - Step[832,938] - Loss: 1.8141 - Accuracy: 65.62%
# Epoch[4/20] - Step[896,938] - Loss: 1.6409 - Accuracy: 84.38%
# Epoch[5/20] - Step[64,938] - Loss: 1.8312 - Accuracy: 62.50%
# Epoch[5/20] - Step[128,938] - Loss: 1.7550 - Accuracy: 71.88%
# Epoch[5/20] - Step[192,938] - Loss: 1.7514 - Accuracy: 71.88%
# Epoch[5/20] - Step[256,938] - Loss: 1.7951 - Accuracy: 68.75%
# Epoch[5/20] - Step[320,938] - Loss: 1.6888 - Accuracy: 78.12%
# Epoch[5/20] - Step[384,938] - Loss: 1.7838 - Accuracy: 68.75%
# Epoch[5/20] - Step[448,938] - Loss: 1.7004 - Accuracy: 78.12%
# Epoch[5/20] - Step[512,938] - Loss: 1.8204 - Accuracy: 67.19%
# Epoch[5/20] - Step[576,938] - Loss: 1.8530 - Accuracy: 62.50%
# Epoch[5/20] - Step[640,938] - Loss: 1.8272 - Accuracy: 65.62%
# Epoch[5/20] - Step[704,938] - Loss: 1.7687 - Accuracy: 70.31%
# Epoch[5/20] - Step[768,938] - Loss: 1.7119 - Accuracy: 76.56%
# Epoch[5/20] - Step[832,938] - Loss: 1.7035 - Accuracy: 79.69%
# Epoch[5/20] - Step[896,938] - Loss: 1.7172 - Accuracy: 78.12%
# Epoch[6/20] - Step[64,938] - Loss: 1.6873 - Accuracy: 81.25%
# Epoch[6/20] - Step[128,938] - Loss: 1.7017 - Accuracy: 76.56%
# Epoch[6/20] - Step[192,938] - Loss: 1.7435 - Accuracy: 75.00%
# Epoch[6/20] - Step[256,938] - Loss: 1.7355 - Accuracy: 73.44%
# Epoch[6/20] - Step[320,938] - Loss: 1.7489 - Accuracy: 71.88%
# Epoch[6/20] - Step[384,938] - Loss: 1.6704 - Accuracy: 81.25%
# Epoch[6/20] - Step[448,938] - Loss: 1.6935 - Accuracy: 76.56%
# Epoch[6/20] - Step[512,938] - Loss: 1.7608 - Accuracy: 70.31%
# Epoch[6/20] - Step[576,938] - Loss: 1.7449 - Accuracy: 70.31%
# Epoch[6/20] - Step[640,938] - Loss: 1.6575 - Accuracy: 82.81%
# Epoch[6/20] - Step[704,938] - Loss: 1.6365 - Accuracy: 81.25%
# Epoch[6/20] - Step[768,938] - Loss: 1.7353 - Accuracy: 73.44%
# Epoch[6/20] - Step[832,938] - Loss: 1.6787 - Accuracy: 81.25%
# Epoch[6/20] - Step[896,938] - Loss: 1.6242 - Accuracy: 84.38%
# Epoch[7/20] - Step[64,938] - Loss: 1.7024 - Accuracy: 75.00%
# Epoch[7/20] - Step[128,938] - Loss: 1.6719 - Accuracy: 76.56%
# Epoch[7/20] - Step[192,938] - Loss: 1.6423 - Accuracy: 82.81%
# Epoch[7/20] - Step[256,938] - Loss: 1.7743 - Accuracy: 70.31%
# Epoch[7/20] - Step[320,938] - Loss: 1.7503 - Accuracy: 68.75%
# Epoch[7/20] - Step[384,938] - Loss: 1.6933 - Accuracy: 78.12%
# Epoch[7/20] - Step[448,938] - Loss: 1.6492 - Accuracy: 81.25%
# Epoch[7/20] - Step[512,938] - Loss: 1.7475 - Accuracy: 71.88%
# Epoch[7/20] - Step[576,938] - Loss: 1.6564 - Accuracy: 82.81%
# Epoch[7/20] - Step[640,938] - Loss: 1.7122 - Accuracy: 75.00%
# Epoch[7/20] - Step[704,938] - Loss: 1.7354 - Accuracy: 70.31%
# Epoch[7/20] - Step[768,938] - Loss: 1.6559 - Accuracy: 81.25%
# Epoch[7/20] - Step[832,938] - Loss: 1.6115 - Accuracy: 85.94%
# Epoch[7/20] - Step[896,938] - Loss: 1.6768 - Accuracy: 81.25%
# Epoch[8/20] - Step[64,938] - Loss: 1.6349 - Accuracy: 82.81%
# Epoch[8/20] - Step[128,938] - Loss: 1.5964 - Accuracy: 87.50%
# Epoch[8/20] - Step[192,938] - Loss: 1.7340 - Accuracy: 71.88%
# Epoch[8/20] - Step[256,938] - Loss: 1.6794 - Accuracy: 79.69%
# Epoch[8/20] - Step[320,938] - Loss: 1.6866 - Accuracy: 76.56%
# Epoch[8/20] - Step[384,938] - Loss: 1.6899 - Accuracy: 76.56%
# Epoch[8/20] - Step[448,938] - Loss: 1.6723 - Accuracy: 79.69%
# Epoch[8/20] - Step[512,938] - Loss: 1.6506 - Accuracy: 79.69%
# Epoch[8/20] - Step[576,938] - Loss: 1.6999 - Accuracy: 76.56%
# Epoch[8/20] - Step[640,938] - Loss: 1.7089 - Accuracy: 75.00%
# Epoch[8/20] - Step[704,938] - Loss: 1.6203 - Accuracy: 85.94%
# Epoch[8/20] - Step[768,938] - Loss: 1.6732 - Accuracy: 78.12%
# Epoch[8/20] - Step[832,938] - Loss: 1.6661 - Accuracy: 79.69%
# Epoch[8/20] - Step[896,938] - Loss: 1.6760 - Accuracy: 79.69%
# Epoch[9/20] - Step[64,938] - Loss: 1.6226 - Accuracy: 84.38%
# Epoch[9/20] - Step[128,938] - Loss: 1.5923 - Accuracy: 87.50%
# Epoch[9/20] - Step[192,938] - Loss: 1.6747 - Accuracy: 79.69%
# Epoch[9/20] - Step[256,938] - Loss: 1.6453 - Accuracy: 84.38%
# Epoch[9/20] - Step[320,938] - Loss: 1.6235 - Accuracy: 84.38%
# Epoch[9/20] - Step[384,938] - Loss: 1.5803 - Accuracy: 87.50%
# Epoch[9/20] - Step[448,938] - Loss: 1.6153 - Accuracy: 82.81%
# Epoch[9/20] - Step[512,938] - Loss: 1.5652 - Accuracy: 90.62%
# Epoch[9/20] - Step[576,938] - Loss: 1.6667 - Accuracy: 81.25%
# Epoch[9/20] - Step[640,938] - Loss: 1.6837 - Accuracy: 79.69%
# Epoch[9/20] - Step[704,938] - Loss: 1.6339 - Accuracy: 82.81%
# Epoch[9/20] - Step[768,938] - Loss: 1.6632 - Accuracy: 79.69%
# Epoch[9/20] - Step[832,938] - Loss: 1.5967 - Accuracy: 87.50%
# Epoch[9/20] - Step[896,938] - Loss: 1.5809 - Accuracy: 85.94%
# Epoch[10/20] - Step[64,938] - Loss: 1.6648 - Accuracy: 82.81%
# Epoch[10/20] - Step[128,938] - Loss: 1.6931 - Accuracy: 76.56%
# Epoch[10/20] - Step[192,938] - Loss: 1.5729 - Accuracy: 87.50%
# Epoch[10/20] - Step[256,938] - Loss: 1.5691 - Accuracy: 90.62%
# Epoch[10/20] - Step[320,938] - Loss: 1.6899 - Accuracy: 78.12%
# Epoch[10/20] - Step[384,938] - Loss: 1.6552 - Accuracy: 81.25%
# Epoch[10/20] - Step[448,938] - Loss: 1.7308 - Accuracy: 71.88%
# Epoch[10/20] - Step[512,938] - Loss: 1.6215 - Accuracy: 84.38%
# Epoch[10/20] - Step[576,938] - Loss: 1.6559 - Accuracy: 78.12%
# Epoch[10/20] - Step[640,938] - Loss: 1.6022 - Accuracy: 87.50%
# Epoch[10/20] - Step[704,938] - Loss: 1.5636 - Accuracy: 90.62%
# Epoch[10/20] - Step[768,938] - Loss: 1.5965 - Accuracy: 87.50%
# Epoch[10/20] - Step[832,938] - Loss: 1.6311 - Accuracy: 82.81%
# Epoch[10/20] - Step[896,938] - Loss: 1.5747 - Accuracy: 89.06%
# Epoch[11/20] - Step[64,938] - Loss: 1.6115 - Accuracy: 85.94%
# Epoch[11/20] - Step[128,938] - Loss: 1.6286 - Accuracy: 82.81%
# Epoch[11/20] - Step[192,938] - Loss: 1.6877 - Accuracy: 78.12%
# Epoch[11/20] - Step[256,938] - Loss: 1.6392 - Accuracy: 82.81%
# Epoch[11/20] - Step[320,938] - Loss: 1.5371 - Accuracy: 92.19%
# Epoch[11/20] - Step[384,938] - Loss: 1.6072 - Accuracy: 85.94%
# Epoch[11/20] - Step[448,938] - Loss: 1.6081 - Accuracy: 85.94%
# Epoch[11/20] - Step[512,938] - Loss: 1.5862 - Accuracy: 89.06%
# Epoch[11/20] - Step[576,938] - Loss: 1.6451 - Accuracy: 81.25%
# Epoch[11/20] - Step[640,938] - Loss: 1.6178 - Accuracy: 84.38%
# Epoch[11/20] - Step[704,938] - Loss: 1.6225 - Accuracy: 84.38%
# Epoch[11/20] - Step[768,938] - Loss: 1.6364 - Accuracy: 84.38%
# Epoch[11/20] - Step[832,938] - Loss: 1.5598 - Accuracy: 92.19%
# Epoch[11/20] - Step[896,938] - Loss: 1.6646 - Accuracy: 81.25%
# Epoch[12/20] - Step[64,938] - Loss: 1.5554 - Accuracy: 93.75%
# Epoch[12/20] - Step[128,938] - Loss: 1.5720 - Accuracy: 89.06%
# Epoch[12/20] - Step[192,938] - Loss: 1.5753 - Accuracy: 89.06%
# Epoch[12/20] - Step[256,938] - Loss: 1.6737 - Accuracy: 78.12%
# Epoch[12/20] - Step[320,938] - Loss: 1.5734 - Accuracy: 89.06%
# Epoch[12/20] - Step[384,938] - Loss: 1.6141 - Accuracy: 84.38%
# Epoch[12/20] - Step[448,938] - Loss: 1.5853 - Accuracy: 89.06%
# Epoch[12/20] - Step[512,938] - Loss: 1.5840 - Accuracy: 87.50%
# Epoch[12/20] - Step[576,938] - Loss: 1.5929 - Accuracy: 87.50%
# Epoch[12/20] - Step[640,938] - Loss: 1.6324 - Accuracy: 82.81%
# Epoch[12/20] - Step[704,938] - Loss: 1.6454 - Accuracy: 82.81%
# Epoch[12/20] - Step[768,938] - Loss: 1.5587 - Accuracy: 89.06%
# Epoch[12/20] - Step[832,938] - Loss: 1.7014 - Accuracy: 76.56%
# Epoch[12/20] - Step[896,938] - Loss: 1.6891 - Accuracy: 78.12%
# Epoch[13/20] - Step[64,938] - Loss: 1.5931 - Accuracy: 87.50%
# Epoch[13/20] - Step[128,938] - Loss: 1.6045 - Accuracy: 85.94%
# Epoch[13/20] - Step[192,938] - Loss: 1.6020 - Accuracy: 85.94%
# Epoch[13/20] - Step[256,938] - Loss: 1.5976 - Accuracy: 85.94%
# Epoch[13/20] - Step[320,938] - Loss: 1.5853 - Accuracy: 89.06%
# Epoch[13/20] - Step[384,938] - Loss: 1.5689 - Accuracy: 87.50%
# Epoch[13/20] - Step[448,938] - Loss: 1.6046 - Accuracy: 85.94%
# Epoch[13/20] - Step[512,938] - Loss: 1.6056 - Accuracy: 87.50%
# Epoch[13/20] - Step[576,938] - Loss: 1.6384 - Accuracy: 81.25%
# Epoch[13/20] - Step[640,938] - Loss: 1.6002 - Accuracy: 85.94%
# Epoch[13/20] - Step[704,938] - Loss: 1.5691 - Accuracy: 89.06%
# Epoch[13/20] - Step[768,938] - Loss: 1.6764 - Accuracy: 78.12%
# Epoch[13/20] - Step[832,938] - Loss: 1.6442 - Accuracy: 81.25%
# Epoch[13/20] - Step[896,938] - Loss: 1.7037 - Accuracy: 75.00%
# Epoch[14/20] - Step[64,938] - Loss: 1.5728 - Accuracy: 89.06%
# Epoch[14/20] - Step[128,938] - Loss: 1.5530 - Accuracy: 90.62%
# Epoch[14/20] - Step[192,938] - Loss: 1.5677 - Accuracy: 90.62%
# Epoch[14/20] - Step[256,938] - Loss: 1.6390 - Accuracy: 84.38%
# Epoch[14/20] - Step[320,938] - Loss: 1.5768 - Accuracy: 90.62%
# Epoch[14/20] - Step[384,938] - Loss: 1.5581 - Accuracy: 90.62%
# Epoch[14/20] - Step[448,938] - Loss: 1.6620 - Accuracy: 79.69%
# Epoch[14/20] - Step[512,938] - Loss: 1.6483 - Accuracy: 81.25%
# Epoch[14/20] - Step[576,938] - Loss: 1.6449 - Accuracy: 81.25%
# Epoch[14/20] - Step[640,938] - Loss: 1.6429 - Accuracy: 82.81%
# Epoch[14/20] - Step[704,938] - Loss: 1.6325 - Accuracy: 84.38%
# Epoch[14/20] - Step[768,938] - Loss: 1.6600 - Accuracy: 79.69%
# Epoch[14/20] - Step[832,938] - Loss: 1.5551 - Accuracy: 90.62%
# Epoch[14/20] - Step[896,938] - Loss: 1.6189 - Accuracy: 84.38%
# Epoch[15/20] - Step[64,938] - Loss: 1.5440 - Accuracy: 92.19%
# Epoch[15/20] - Step[128,938] - Loss: 1.6321 - Accuracy: 82.81%
# Epoch[15/20] - Step[192,938] - Loss: 1.6109 - Accuracy: 85.94%
# Epoch[15/20] - Step[256,938] - Loss: 1.6651 - Accuracy: 79.69%
# Epoch[15/20] - Step[320,938] - Loss: 1.6449 - Accuracy: 81.25%
# Epoch[15/20] - Step[384,938] - Loss: 1.5879 - Accuracy: 85.94%
# Epoch[15/20] - Step[448,938] - Loss: 1.6233 - Accuracy: 84.38%
# Epoch[15/20] - Step[512,938] - Loss: 1.5470 - Accuracy: 92.19%
# Epoch[15/20] - Step[576,938] - Loss: 1.6594 - Accuracy: 81.25%
# Epoch[15/20] - Step[640,938] - Loss: 1.5920 - Accuracy: 87.50%
# Epoch[15/20] - Step[704,938] - Loss: 1.5421 - Accuracy: 92.19%
# Epoch[15/20] - Step[768,938] - Loss: 1.5997 - Accuracy: 85.94%
# Epoch[15/20] - Step[832,938] - Loss: 1.5772 - Accuracy: 89.06%
# Epoch[15/20] - Step[896,938] - Loss: 1.6268 - Accuracy: 82.81%
# Epoch[16/20] - Step[64,938] - Loss: 1.5563 - Accuracy: 90.62%
# Epoch[16/20] - Step[128,938] - Loss: 1.5455 - Accuracy: 92.19%
# Epoch[16/20] - Step[192,938] - Loss: 1.5905 - Accuracy: 87.50%
# Epoch[16/20] - Step[256,938] - Loss: 1.6361 - Accuracy: 82.81%
# Epoch[16/20] - Step[320,938] - Loss: 1.6170 - Accuracy: 84.38%
# Epoch[16/20] - Step[384,938] - Loss: 1.6025 - Accuracy: 85.94%
# Epoch[16/20] - Step[448,938] - Loss: 1.6362 - Accuracy: 82.81%
# Epoch[16/20] - Step[512,938] - Loss: 1.5857 - Accuracy: 87.50%
# Epoch[16/20] - Step[576,938] - Loss: 1.6062 - Accuracy: 85.94%
# Epoch[16/20] - Step[640,938] - Loss: 1.6389 - Accuracy: 82.81%
# Epoch[16/20] - Step[704,938] - Loss: 1.6865 - Accuracy: 78.12%
# Epoch[16/20] - Step[768,938] - Loss: 1.5902 - Accuracy: 87.50%
# Epoch[16/20] - Step[832,938] - Loss: 1.5646 - Accuracy: 90.62%
# Epoch[16/20] - Step[896,938] - Loss: 1.5845 - Accuracy: 89.06%
# Epoch[17/20] - Step[64,938] - Loss: 1.6312 - Accuracy: 84.38%
# Epoch[17/20] - Step[128,938] - Loss: 1.5647 - Accuracy: 90.62%
# Epoch[17/20] - Step[192,938] - Loss: 1.6320 - Accuracy: 82.81%
# Epoch[17/20] - Step[256,938] - Loss: 1.6157 - Accuracy: 84.38%
# Epoch[17/20] - Step[320,938] - Loss: 1.6234 - Accuracy: 84.38%
# Epoch[17/20] - Step[384,938] - Loss: 1.5230 - Accuracy: 93.75%
# Epoch[17/20] - Step[448,938] - Loss: 1.6587 - Accuracy: 79.69%
# Epoch[17/20] - Step[512,938] - Loss: 1.4960 - Accuracy: 96.88%
# Epoch[17/20] - Step[576,938] - Loss: 1.6098 - Accuracy: 84.38%
# Epoch[17/20] - Step[640,938] - Loss: 1.5766 - Accuracy: 89.06%
# Epoch[17/20] - Step[704,938] - Loss: 1.5981 - Accuracy: 87.50%
# Epoch[17/20] - Step[768,938] - Loss: 1.5795 - Accuracy: 87.50%
# Epoch[17/20] - Step[832,938] - Loss: 1.5589 - Accuracy: 90.62%
# Epoch[17/20] - Step[896,938] - Loss: 1.5762 - Accuracy: 87.50%
# Epoch[18/20] - Step[64,938] - Loss: 1.6462 - Accuracy: 81.25%
# Epoch[18/20] - Step[128,938] - Loss: 1.5470 - Accuracy: 92.19%
# Epoch[18/20] - Step[192,938] - Loss: 1.5000 - Accuracy: 96.88%
# Epoch[18/20] - Step[256,938] - Loss: 1.6191 - Accuracy: 84.38%
# Epoch[18/20] - Step[320,938] - Loss: 1.6139 - Accuracy: 84.38%
# Epoch[18/20] - Step[384,938] - Loss: 1.4959 - Accuracy: 96.88%
# Epoch[18/20] - Step[448,938] - Loss: 1.5461 - Accuracy: 92.19%
# Epoch[18/20] - Step[512,938] - Loss: 1.5217 - Accuracy: 95.31%
# Epoch[18/20] - Step[576,938] - Loss: 1.5473 - Accuracy: 92.19%
# Epoch[18/20] - Step[640,938] - Loss: 1.5171 - Accuracy: 95.31%
# Epoch[18/20] - Step[704,938] - Loss: 1.5515 - Accuracy: 92.19%
# Epoch[18/20] - Step[768,938] - Loss: 1.5573 - Accuracy: 90.62%
# Epoch[18/20] - Step[832,938] - Loss: 1.5219 - Accuracy: 95.31%
# Epoch[18/20] - Step[896,938] - Loss: 1.5636 - Accuracy: 90.62%
# Epoch[19/20] - Step[64,938] - Loss: 1.4970 - Accuracy: 96.88%
# Epoch[19/20] - Step[128,938] - Loss: 1.5390 - Accuracy: 93.75%
# Epoch[19/20] - Step[192,938] - Loss: 1.5568 - Accuracy: 90.62%
# Epoch[19/20] - Step[256,938] - Loss: 1.5163 - Accuracy: 95.31%
# Epoch[19/20] - Step[320,938] - Loss: 1.5101 - Accuracy: 96.88%
# Epoch[19/20] - Step[384,938] - Loss: 1.5191 - Accuracy: 93.75%
# Epoch[19/20] - Step[448,938] - Loss: 1.5733 - Accuracy: 89.06%
# Epoch[19/20] - Step[512,938] - Loss: 1.5114 - Accuracy: 95.31%
# Epoch[19/20] - Step[576,938] - Loss: 1.5394 - Accuracy: 92.19%
# Epoch[19/20] - Step[640,938] - Loss: 1.5432 - Accuracy: 92.19%
# Epoch[19/20] - Step[704,938] - Loss: 1.5425 - Accuracy: 90.62%
# Epoch[19/20] - Step[768,938] - Loss: 1.4958 - Accuracy: 95.31%
# Epoch[19/20] - Step[832,938] - Loss: 1.5407 - Accuracy: 92.19%
# Epoch[19/20] - Step[896,938] - Loss: 1.5531 - Accuracy: 92.19%
# Epoch[20/20] - Step[64,938] - Loss: 1.5211 - Accuracy: 93.75%
# Epoch[20/20] - Step[128,938] - Loss: 1.5054 - Accuracy: 96.88%
# Epoch[20/20] - Step[192,938] - Loss: 1.5543 - Accuracy: 90.62%
# Epoch[20/20] - Step[256,938] - Loss: 1.5228 - Accuracy: 93.75%
# Epoch[20/20] - Step[320,938] - Loss: 1.5332 - Accuracy: 92.19%
# Epoch[20/20] - Step[384,938] - Loss: 1.5416 - Accuracy: 90.62%
# Epoch[20/20] - Step[448,938] - Loss: 1.5420 - Accuracy: 90.62%
# Epoch[20/20] - Step[512,938] - Loss: 1.5315 - Accuracy: 92.19%
# Epoch[20/20] - Step[576,938] - Loss: 1.4785 - Accuracy: 98.44%
# Epoch[20/20] - Step[640,938] - Loss: 1.5582 - Accuracy: 90.62%
# Epoch[20/20] - Step[704,938] - Loss: 1.5336 - Accuracy: 93.75%
# Epoch[20/20] - Step[768,938] - Loss: 1.4851 - Accuracy: 98.44%
# Epoch[20/20] - Step[832,938] - Loss: 1.5332 - Accuracy: 93.75%
# Epoch[20/20] - Step[896,938] - Loss: 1.5186 - Accuracy: 95.31%

# %%
#test
model.eval()
with torch.no_grad():
  correct=0
  total=0
  for images,labels in testLoader:
    images = images.to(device)
    labels = labels.to(device)
    outputs=model(images)
    _,predicted=torch.max(outputs.data,1)
    total+=labels.size(0)
    correct+=(predicted==labels).sum().item()
  
  print('Test Accuracy of the model on the 1w test images: {}%'.format((correct/total)*100))
# Out:
# Test Accuracy of the model on the 1w test images: 96.5%
